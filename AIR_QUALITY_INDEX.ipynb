# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsingh1609/Air-Quality-Index/blob/main/AIR_QUALITY_INDEX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/air_quality_data.xlsx")
df.head()
# Out:
#           City       Date   PM2.5    PM10     NO2     SO2      O3     CO  \
# 0      Bangkok 2025-03-12   94.23  276.33   67.16    9.75  178.14  21.84
# 1  Los Angeles 2025-07-01  135.58  288.69   13.05   50.55   10.18  19.63
# 2        Seoul 2025-06-09  224.44  265.02  170.51   95.92   20.05  20.54
# 3        Perth 2025-04-09    9.38  184.76  121.44   30.91   77.42  12.00
# 4     Istanbul 2025-02-08  201.66  130.48  148.59  122.18   53.46  31.12
#
#    Temperature  AQI
# 0        28.86   75
# 1        -9.76  278
# 2        21.44  385
# 3        -4.57  163
# 4        30.71  244

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         2000 non-null   object
#  1   Date         2000 non-null   datetime64[ns]
#  2   PM2.5        2000 non-null   float64
#  3   PM10         2000 non-null   float64
#  4   NO2          2000 non-null   float64
#  5   SO2          2000 non-null   float64
#  6   O3           2000 non-null   float64
#  7   CO           2000 non-null   float64
#  8   Temperature  2000 non-null   float64
#  9   AQI          2000 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#                              Date       PM2.5         PM10          NO2  \
# count                        2000  2000.00000  2000.000000  2000.000000
# mean   2025-01-27 00:20:52.800000   126.25294   149.731325   101.391910
# min           2024-07-30 00:00:00     0.17000     0.070000     0.030000
# 25%           2024-10-30 00:00:00    62.11750    74.277500    52.607500
# 50%           2025-01-29 00:00:00   128.51500   150.430000   100.545000
# 75%           2025-04-21 06:00:00   190.40500   225.470000   151.910000
# max           2025-07-30 00:00:00   249.95000   299.340000   199.920000
# std                           NaN    73.32984    86.683480    58.203991
#
#               SO2           O3           CO  Temperature          AQI
# count  2000.00000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     74.11102    90.139880    25.302940    17.665650   251.246000
# min       0.11000     0.040000     0.030000    -9.980000     0.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['City'] = label_encoder.fit_transform(df['City'])

# %%
label_encoder = LabelEncoder()
df['Date'] = label_encoder.fit_transform(df['Date'])

# %%
df.head()
# Out:
#    City  Date   PM2.5    PM10     NO2     SO2      O3     CO  Temperature  AQI
# 0     3   223   94.23  276.33   67.16    9.75  178.14  21.84        28.86   75
# 1    23   333  135.58  288.69   13.05   50.55   10.18  19.63        -9.76  278
# 2    43   311  224.44  265.02  170.51   95.92   20.05  20.54        21.44  385
# 3    34   251    9.38  184.76  121.44   30.91   77.42  12.00        -4.57  163
# 4    17   191  201.66  130.48  148.59  122.18   53.46  31.12        30.71  244

# %%
x = df.drop(columns=["AQI"])  # Features
y = df["AQI"]  # Target variable

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Then apply StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# Print results
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 119.54930248908829
# Mean Squared Error: 19044.073441792574
# R-squared Score: 0.00488170724307635
